# %%
from vectordb import VectorDB

db = VectorDB("../../data/vectordb/chroma/", "ernie")

# %%
search_input = {"query":"饭桌上应该怎么坐","type":1}
search_result = db.search(search_input)

# %%
search_result
# Out:
# [(Document(page_content="注意事项: ['需根据不同场合选择合适的万能公式，并且在实际应用时需要灵活应变。']\n\n###\n\n关键词: 餐桌礼仪\n\n应用场景: 商务场合中的餐饮活动\n\n具体内容: 餐桌礼仪涉及安排座位，座次根据人的地位和级别来安排，主座通常面对门口正中间，适合东道主或级别最高的领导或客人坐。在敬酒时，需要等到自己的领导或客人敬酒结束后才能去敬酒，敬酒时要起身站立，双手举杯，杯口要低于对方，同时要准备敬酒词。此外，还有一些餐桌上的注意事项，如使用公筷公勺为客人夹菜，吃饭时不发出声响，不当众剔牙等\n\n注意事项: 需要根据人物的身份和地位来安排座位，同时敬酒的顺序和方式也有讲究，以及餐桌上的行为举止需要注意礼貌和尊重他人\n\n###\n\n关键词: 第六大套路、名人名言、祝福\n\n应用场景: 适用于任何即兴发言场合，如聚餐、聚会等\n\n具体内容: 第六大套路公式是称呼加名人名言加回忆过去加祝福未来。这里的名人名言可以是俗语、言语、歇后语等。在祝福部分，可以举例如祝福新人新婚快乐、百年好合、早生贵子，同时祝福来宾及家人身体健康、工作顺利、心想事成、万事如意。\n\n注意事项: 无\n\n###", metadata={'source': '../../data/corpus/1敬酒/knowledges.txt'}),
#   0.9047534561664903),
# ...
